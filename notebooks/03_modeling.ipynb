# %% [markdown]
# # 03 - Modeling Notebook
# Train and compare regression + classification candidates.

# %%
import pandas as pd
from training.feature_selection import run_feature_selection
from training.train_models import train_and_select_models

df = pd.read_csv('../data/processed/engineered_dataset.csv')
fs = run_feature_selection(df, 'clv')
res = train_and_select_models(df, 'clv', fs.shortlisted_features, 0.8, {'dataset_type':'notebook','data_source':'engineered','notes':[]})
res.regression_metrics
