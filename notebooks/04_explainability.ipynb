# %% [markdown]
# # 04 - Explainability Notebook
# Generate SHAP/fallback importance and recommendations.

# %%
import pandas as pd
from training.explain_model import run_explainability

df = pd.read_csv('../data/processed/engineered_dataset.csv')
features = [c for c in df.columns if c not in ['clv', 'customer_id']]
run_explainability(df, 'clv', features)
