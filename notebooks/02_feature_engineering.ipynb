# %% [markdown]
# # 02 - Feature Engineering Notebook
# RFM and adaptive engineered features are generated here.

# %%
from training.preprocess import load_input_csv
from training.feature_engineering import engineer_features

df = load_input_csv('../data/raw/customer_clv_row_level.csv')
result = engineer_features(df, 'clv')
result.dataframe.head()
