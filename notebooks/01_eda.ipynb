# %% [markdown]
# # 01 - EDA Notebook
# This notebook reproduces data profiling and EDA outputs used in the dashboard.

# %%
import pandas as pd
from training.preprocess import load_input_csv, perform_eda

df = load_input_csv('../data/raw/customer_clv_row_level.csv')
perform_eda(df, 'clv')
df.head()
